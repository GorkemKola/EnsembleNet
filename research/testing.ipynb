# %%
# %pwd
# %cd ..
# Out:
# /home/gorkemkola/Desktop/Projects/cv_project

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import pandas as pd
import numpy as np
from pathlib import Path
from dataclasses import dataclass
# import datasets.ImageFolder
from torchvision import datasets
from typing import Dict, List, Tuple, Optional
import json
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_auc_score,
    precision_recall_curve, roc_curve
)
import warnings
warnings.filterwarnings('ignore')

from ensemblenet import logger
from ensemblenet.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
from ensemblenet.utils import read_yaml, create_directories
from torchvision import models, transforms

# %%
@dataclass(frozen=True)
class TestConfig:
    root_dir: Path
    models_dir: Path
    results_dir: Path
    test_dir: Path
    best_model_paths: List[Path]
    hyperparams_paths: List[Path]
    model_names: List[str]
    params: Dict[str, any]
    hyperparams: List[pd.DataFrame]
    training_metrics: List[pd.DataFrame]
    batch_size: int

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
    ) -> None:
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        create_directories(
            [
                self.config.artifacts_root,
                Path(self.config.test.root_dir),
                Path(self.config.test.results_dir),
            ]
        )

    def get_test_config(self) -> TestConfig:
        # Define model names based on your training artifacts
        model_names = sorted(self.config.test.model_names)
        best_model_paths = [self.config.test.best_model_path_template.format(model_name=name) for name in model_names]
        hyperparams_paths = [self.config.test.hyperparams_path_template.format(model_name=name) for name in model_names]
        hyperparams = [pd.read_csv(path) for path in hyperparams_paths]
        training_metric_paths = [self.config.test.training_metrics_path_template.format(model_name=name) for name in model_names]
        training_metrics = [pd.read_csv(path) for path in training_metric_paths]
        test_config = TestConfig(
            root_dir=Path(self.config.test.root_dir),
            models_dir=Path(self.config.test.models_dir),
            results_dir=Path(self.config.test.results_dir),
            test_dir=Path(self.config.data_ingestion.test_dir),
            best_model_paths=best_model_paths,
            hyperparams_paths=hyperparams_paths,
            model_names=model_names,
            params=self.params,
            hyperparams=hyperparams,
            training_metrics=training_metrics,
            batch_size=self.params.BATCH_SIZE
        )
        
        return test_config

# %%
ConfigurationManager().get_test_config()
# Out:
# [2025-06-21 09:22:38,554: INFO: utils: yaml file config/config.yaml loaded successfully:]
# [2025-06-21 09:22:38,559: INFO: utils: yaml file config/params.yaml loaded successfully:]
# [2025-06-21 09:22:38,560: INFO: utils: created directory at: artifacts:]
# [2025-06-21 09:22:38,561: INFO: utils: created directory at: artifacts/test:]
# [2025-06-21 09:22:38,561: INFO: utils: created directory at: artifacts/test/results:]
# TestConfig(root_dir=PosixPath('artifacts/test'), models_dir=PosixPath('artifacts/training'), results_dir=PosixPath('artifacts/test/results'), test_dir=PosixPath('artifacts/data_ingestion/test'), best_model_paths=['artifacts/training/model_ensemblenet_best.pth', 'artifacts/training/model_ensemblenet1_best.pth', 'artifacts/training/model_inception_v3_best.pth', 'artifacts/training/model_mnasnet_best.pth', 'artifacts/training/model_mobilenet_best.pth', 'artifacts/training/model_mobilenet_best.pth', 'artifacts/training/model_resnet_best.pth', 'artifacts/training/model_shufflenet_best.pth', 'artifacts/training/model_squeezenet_best.pth', 'artifacts/training/model_vit_best.pth'], hyperparams_paths=['artifacts/training/logs/hyperparameters_ensemblenet.csv', 'artifacts/training/logs/hyperparameters_ensemblenet1.csv', 'artifacts/training/logs/hyperparameters_inception_v3.csv', 'artifacts/training/logs/hyperparameters_mnasnet.csv', 'artifacts/training/logs/hyperparameters_mobilenet.csv', 'artifacts/training/logs/hyperparameters_mobilenet.csv', 'artifacts/training/logs/hyperparameters_resnet.csv', 'artifacts/training/logs/hyperparameters_shufflenet.csv', 'artifacts/training/logs/hyperparameters_squeezenet.csv', 'artifacts/training/logs/hyperparameters_vit.csv'], model_names=['ensemblenet', 'ensemblenet1', 'inception_v3', 'mnasnet', 'mobilenet', 'mobilenet', 'resnet', 'shufflenet', 'squeezenet', 'vit'], params=ConfigBox({'AUGMENTATION': True, 'IMAGE_SIZE': [224, 224, 3], 'BATCH_SIZE': 16, 'INCLUDE_TOP': False, 'EPOCHS': 100, 'CLASSES': 257, 'PRETRAINED_WEIGHTS': 'IMAGENET1K_V1', 'LEARNING_RATE': 0.01, 'FIND_LR': True, 'EARLY_STOPPING_PATIENCE': 11, 'RANDOM_STATE': 42, 'BASE_MODEL_NAMES': ['squeezenet', 'shufflenet', 'mobilenet'], 'EMBED_DIM': 384, 'ATTENTION_NUM_MODELS': 3, 'MODEL_NAME': 'ensemblenet2', 'FIGSIZE': [15, 12], 'COLOR_PALETTE': 'husl', 'SNS_STYLE': 'whitegrid'}), hyperparams=[                         parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-19T17:58:29.902264
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6       artifacts/training/model_ensemblenet_last.pth
# 7       artifacts/training/model_ensemblenet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                        ensemblenet
# 13                                                257
# 14                                               True
# 15  artifacts/training/lr_finder_plot_ensemblenet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-21T00:23:24.966386
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6      artifacts/training/model_ensemblenet1_last.pth
# 7      artifacts/training/model_ensemblenet1_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                       ensemblenet1
# 13                                                257
# 14                                               True
# 15  artifacts/training/lr_finder_plot_ensemblenet1...
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-07T19:44:48.462756
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6      artifacts/training/model_inception_v3_last.pth
# 7      artifacts/training/model_inception_v3_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                       inception_v3
# 13                                                257
# 14                                               True
# 15  artifacts/training/lr_finder_plot_inception_v3...
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [299, 299, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-15T11:34:03.898842
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6           artifacts/training/model_mnasnet_last.pth
# 7           artifacts/training/model_mnasnet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                            mnasnet
# 13                                                257
# 14                                               True
# 15      artifacts/training/lr_finder_plot_mnasnet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-19T23:16:52.141970
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6         artifacts/training/model_mobilenet_last.pth
# 7         artifacts/training/model_mobilenet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                          mobilenet
# 13                                                257
# 14                                               True
# 15    artifacts/training/lr_finder_plot_mobilenet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-19T23:16:52.141970
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6         artifacts/training/model_mobilenet_last.pth
# 7         artifacts/training/model_mobilenet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                          mobilenet
# 13                                                257
# 14                                               True
# 15    artifacts/training/lr_finder_plot_mobilenet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-06T18:25:58.720952
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6            artifacts/training/model_resnet_last.pth
# 7            artifacts/training/model_resnet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                             resnet
# 13                                                257
# 14                                               True
# 15       artifacts/training/lr_finder_plot_resnet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-15T12:43:42.308040
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6        artifacts/training/model_shufflenet_last.pth
# 7        artifacts/training/model_shufflenet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                         shufflenet
# 13                                                257
# 14                                               True
# 15   artifacts/training/lr_finder_plot_shufflenet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-15T05:33:34.636636
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6        artifacts/training/model_squeezenet_last.pth
# 7        artifacts/training/model_squeezenet_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                         squeezenet
# 13                                                257
# 14                                               True
# 15   artifacts/training/lr_finder_plot_squeezenet.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ,                          parameter  \
# 0                        timestamp
# 1                           device
# 2                    torch_version
# 3                   cuda_available
# 4                     cuda_version
# 5                         root_dir
# 6                  last_model_path
# 7                  best_model_path
# 8                  train_data_path
# 9                  valid_data_path
# 10                  test_data_path
# 11   attention_ensemble_model_path
# 12                      model_name
# 13                     num_classes
# 14                  use_pretrained
# 15             lr_finder_plot_path
# 16                   params_epochs
# 17               params_batch_size
# 18             params_augmentation
# 19               params_image_size
# 20  params_early_stopping_patience
# 21            params_learning_rate
# 22             params_random_state
# 23                  params_find_lr
# 24             total_train_samples
# 25         train_batches_per_epoch
# 26             total_valid_samples
# 27         valid_batches_per_epoch
# 28              total_test_samples
# 29          test_batches_per_epoch
#
#                                                 value
# 0                          2025-06-07T03:38:56.470452
# 1                                                cuda
# 2                                         2.7.0+cu126
# 3                                                True
# 4                                                12.6
# 5                                  artifacts/training
# 6               artifacts/training/model_vit_last.pth
# 7               artifacts/training/model_vit_best.pth
# 8                      artifacts/data_ingestion/train
# 9                        artifacts/data_ingestion/val
# 10                      artifacts/data_ingestion/test
# 11  artifacts/prepare_ensemble_model/attention_ens...
# 12                                                vit
# 13                                                257
# 14                                               True
# 15          artifacts/training/lr_finder_plot_vit.png
# 16                                                100
# 17                                                 16
# 18                                               True
# 19                                      [224, 224, 3]
# 20                                                 11
# 21                                               0.01
# 22                                                 42
# 23                                               True
# 24                                              21307
# 25                                               1332
# 26                                               3273
# 27                                                205
# 28                                               6027
# 29                                                377  ], training_metrics=[    epoch  train_loss  valid_loss   accuracy  precision    recall  f1_score  \
# 0       1    3.069850    1.410533  66.849985   0.713865  0.668500  0.650922
# 1       2    1.403344    1.000599  75.221509   0.789510  0.752215  0.748420
# 2       3    1.052810    0.948179  76.596395   0.795496  0.765964  0.762727
# 3       4    0.833563    0.921835  77.207455   0.804746  0.772075  0.770297
# 4       5    0.691467    0.844332  78.704552   0.810045  0.787046  0.784849
# 5       6    0.566155    0.861445  77.940727   0.811960  0.779407  0.779409
# 6       7    0.478282    0.886592  78.276810   0.805812  0.782768  0.780190
# 7       8    0.386976    0.940332  76.901925   0.818701  0.769019  0.775260
# 8       9    0.239517    0.833252  79.743355   0.813818  0.797434  0.795978
# 9      10    0.198187    0.857155  80.079438   0.818509  0.800794  0.799619
# 10     11    0.168636    0.853254  79.712802   0.819154  0.797128  0.795657
# 11     12    0.157854    0.892940  79.498931   0.817790  0.794989  0.794517
# 12     13    0.103600    0.865039  80.568286   0.823905  0.805683  0.805310
# 13     14    0.081062    0.854315  80.568286   0.821966  0.805683  0.804553
# 14     15    0.076150    0.869826  80.446074   0.822043  0.804461  0.804852
# 15     16    0.055974    0.883827  80.262756   0.814978  0.802628  0.799539
# 16     17    0.052379    0.877816  80.598839   0.815468  0.805988  0.804055
# 17     18    0.041638    0.917633  81.209899   0.823879  0.812099  0.810133
# 18     19    0.039579    0.857218  81.301558   0.825705  0.813016  0.812436
# 19     20    0.034953    0.881116  80.782157   0.819797  0.807822  0.806106
#
#     learning_rate  is_best_model  early_stopping_counter  \
# 
# 32     33    0.000826    0.579662  89.031470   0.897552  0.890315  0.889829
# 33     34    0.000718    0.581832  89.000917   0.896672  0.890009  0.889208
#
#     learning_rate  is_best_model  early_stopping_counter  \
# 0        0.000048           True                       0
# 1        0.000048           True                       0
# 2        0.000048           True                       0
# 3        0.000048           True                       0
# 4        0.000048          False                       0
# 5        0.000048          False                       1
# 6        0.000031          False                       2
# 7        0.000031          False                       3
# 8        0.000031           True                       4
# 9        0.000031          False                       0
# 10       0.000031          False                       1
# 11       0.000019          False                       2
# 12       0.000019          False                       3
# 13       0.000019           True                       4
# 14       0.000019          False                       0
# 15       0.000019          False                       1
# 16       0.000012          False                       2
# 17       0.000012          False                       3
# 18       0.000012          False                       4
# 19       0.000008          False                       5
# 20       0.000008          False                       6
# 21       0.000008          False                       7
# 22       0.000008           True                       8
# 23       0.000008          False                       0
# 24       0.000008          False                       1
# 25       0.000005          False                       2
# 26       0.000005          False                       3
# 27       0.000005          False                       4
# 28       0.000003          False                       5
# 29       0.000003          False                       6
# 30       0.000003          False                       7
# 31       0.000002          False                       8
# 32       0.000002          False                       9
# 33       0.000002          False                      10
#
#                      timestamp
# 0   2025-06-07T04:07:14.214118
# 1   2025-06-07T04:35:27.251934
# 2   2025-06-07T05:03:36.738227
# 3   2025-06-07T05:31:46.113724
# 4   2025-06-07T05:59:55.314318
# 5   2025-06-07T06:28:03.446293
# 6   2025-06-07T06:56:11.307055
# 7   2025-06-07T07:24:20.623500
# 8   2025-06-07T07:52:30.913127
# 9   2025-06-07T08:20:43.737820
# 10  2025-06-07T08:48:57.904287
# 11  2025-06-07T09:17:14.966380
# 12  2025-06-07T09:45:34.011830
# 13  2025-06-07T10:13:54.672430
# 14  2025-06-07T10:42:18.176497
# 15  2025-06-07T11:10:43.646692
# 16  2025-06-07T11:39:09.541831
# 17  2025-06-07T12:07:35.521326
# 18  2025-06-07T12:35:58.126830
# 19  2025-06-07T13:04:16.220786
# 20  2025-06-07T13:32:36.217517
# 21  2025-06-07T14:00:58.939525
# 22  2025-06-07T14:29:20.119403
# 23  2025-06-07T14:57:39.837915
# 24  2025-06-07T15:25:59.234380
# 25  2025-06-07T15:54:15.650557
# 26  2025-06-07T16:22:31.662406
# 27  2025-06-07T16:50:47.490957
# 28  2025-06-07T17:19:05.469355
# 29  2025-06-07T17:47:23.213502
# 30  2025-06-07T18:15:42.516595
# 31  2025-06-07T18:44:02.825923
# 32  2025-06-07T19:12:25.429008
# 33  2025-06-07T19:40:47.858411  ], batch_size=16)

# %%
from ensemblenet.custom_models.ensemblenet import EnsembleNet

# %%
@dataclass(frozen=True)
class Models:
    resnet = models.resnet50
    inceptionnet_v3 = models.inception_v3
    ensemblenet = EnsembleNet
    mnasnet = models.mnasnet0_5
    mobilenet = models.mobilenet_v3_small
    squeezenet = models.squeezenet1_1
    shufflenet = models.shufflenet_v2_x0_5

# %%
model = torch.load(
    ConfigurationManager().get_test_config().best_model_paths[0],
    map_location=torch.device('cpu'),
    weights_only=False
)
# Out:
# [2025-06-21 09:22:38,694: INFO: utils: yaml file config/config.yaml loaded successfully:]
# [2025-06-21 09:22:38,696: INFO: utils: yaml file config/params.yaml loaded successfully:]
# [2025-06-21 09:22:38,697: INFO: utils: created directory at: artifacts:]
# [2025-06-21 09:22:38,697: INFO: utils: created directory at: artifacts/test:]
# [2025-06-21 09:22:38,698: INFO: utils: created directory at: artifacts/test/results:]

# %%
class Test:
    def __init__(self, config: TestConfig) -> None:
        self.config = config
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        logger.info(f"Using device: {self.device}")


    def _load_model(self, model_path: Path) -> nn.Module:
        model = torch.load(
            model_path,
            map_location=torch.device('cpu'),
            weights_only=False
        )
        return model.to(self.device)
    
    def load_models(self) -> List[nn.Module]:
        models = {}
        for i, model_path in enumerate(self.config.best_model_paths):
            model_name = self.config.model_names[i]
            model = self._load_model(model_path)
            models[model_name] = model
            logger.info(f"Loaded model from {model_path}")
            print(f"Loaded model from {model_path}")
        return models
        
    def compute_dataset_mean_std(self, data_dir, image_size=(224, 224), batch_size=64, sample_limit=None):
        """
        Computes mean and std for all images in a directory (ImageFolder structure).
        Uses cached .npy arrays if available, otherwise computes and saves them.
        """
        mean_path = Path(data_dir) / "mean.npy"
        std_path = Path(data_dir) / "std.npy"

        if mean_path.exists() and std_path.exists():
            logger.info(f"Loading cached mean/std from {mean_path} and {std_path}")
            mean = np.load(mean_path)
            std = np.load(std_path)
            return mean.tolist(), std.tolist()

        transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor()
        ])
        dataset = datasets.ImageFolder(data_dir, transform=transform)
        loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=4)

        n_images = 0
        mean = 0.
        std = 0.
        for i, (imgs, _) in enumerate(loader):
            if sample_limit and n_images >= sample_limit:
                break
            imgs = imgs.view(imgs.size(0), imgs.size(1), -1)
            mean += imgs.mean(2).sum(0)
            std += imgs.std(2).sum(0)
            n_images += imgs.size(0)
            if sample_limit and n_images >= sample_limit:
                break

        mean /= n_images
        std /= n_images

        np.save(mean_path, mean.cpu().numpy() if hasattr(mean, "cpu") else mean)
        np.save(std_path, std.cpu().numpy() if hasattr(std, "cpu") else std)
        logger.info(f"Saved computed mean/std to {mean_path} and {std_path}")

        return mean.tolist(), std.tolist()
    
    def load_test_dataset(self, data_dir: Path, image_size=(224, 224), batch_size=64, sample_limit=None):
        """
        Loads the test dataset from the specified directory.
        """
        mean, std = self.compute_dataset_mean_std(data_dir, image_size, batch_size, sample_limit)
        transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=mean, std=std)
        ])
        dataset = datasets.ImageFolder(data_dir, transform=transform)
        loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=4)
        return loader
    
    def evaluate_model(self, model_name, model: nn.Module, dataloader: DataLoader) -> Dict[str, float]:
        """
        Evaluates the model on the given dataloader.
        Returns a dictionary with accuracy, precision, recall, f1-score, and AUC.
        """
        
        model.eval()
        all_preds = []
        all_labels = []
        # compute evaluation time
        logger.info(f"Evaluating model: {model.__class__.__name__}")
        print(f"Evaluating model: {model.__class__.__name__}")
        start_time = torch.cuda.Event(enable_timing=True) if self.device.type == 'cuda' else None
        if start_time:
            start_time.record()
        criterion = nn.CrossEntropyLoss()
        losses = []
        
        # add top5 accuracy
        top5_correct = 0
        top5_total = 0
        if start_time:
            start_time.record()
        if self.device.type == 'cuda':
            model = model.to(self.device)
            criterion = criterion.to(self.device)
        else:
            model = model.cpu()
            criterion = criterion.cpu()
        
        with torch.no_grad():
            for images, labels in dataloader:
                images = images.to(self.device)
                labels = labels.to(self.device)
                
                outputs = model(images)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)
                losses.append(loss.item())
                # Store predictions and labels
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
                # Compute top-5 accuracy
                _, top5_preds = torch.topk(outputs, 5, dim=1)
                top5_correct += (top5_preds == labels.view(-1, 1)).sum().item()
                top5_total += labels.size(0)
        # Compute top-5 accuracy
        top5_accuracy = top5_correct / top5_total if top5_total > 0 else 0
        logger.info(f"Top-5 Accuracy: {top5_accuracy:.4f}")
        
        if start_time:
            end_time = torch.cuda.Event(enable_timing=True)
            end_time.record()
            torch.cuda.synchronize()
            eval_time = start_time.elapsed_time(end_time) / 1000  # Convert to seconds
        
        loss = np.mean(losses)
        accuracy = accuracy_score(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
        recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
        f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
        # Compute confusion matrix and classification report
            
        results_path = self.config.results_dir / "results.csv"
        if not results_path.exists():
            pd.DataFrame(columns=["model", "loss", "accuracy", "top 5 accuracy", "precision", "recall", "f1"]).to_csv(results_path, index=False)
        results_df = pd.read_csv(results_path)
        new_row = {
            "model": model_name,
            "loss": loss,
            "accuracy": accuracy,
            "top 5 accuracy": top5_accuracy,
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "time": eval_time if start_time else None
        }

        new_row = pd.DataFrame([new_row])
        results_df = pd.concat([results_df, new_row], ignore_index=True)
        results_df.to_csv(results_path, index=False)
        logger.info(f"Saved evaluation results to {results_path}")

    def evaluate_all_models(self):
        """
        Loads all models and evaluates them
        """
        models = self.load_models()
        test_loader = self.load_test_dataset(self.config.test_dir, 
                                             image_size=(224, 224), 
                                             batch_size=self.config.batch_size, )
        
        for model_name, model in models.items():
            logger.info(f"Evaluating model: {model_name}")
            self.evaluate_model(model_name, model, test_loader)

# %%
if __name__ == "__main__":
    config_manager = ConfigurationManager()
    test_config = config_manager.get_test_config()
    test_instance = Test(test_config)
    test_instance.evaluate_all_models()
    logger.info("Testing completed and metrics plots saved.")
# Out:
# [2025-06-21 09:22:38,979: INFO: utils: yaml file config/config.yaml loaded successfully:]
# [2025-06-21 09:22:38,982: INFO: utils: yaml file config/params.yaml loaded successfully:]
# [2025-06-21 09:22:38,983: INFO: utils: created directory at: artifacts:]
# [2025-06-21 09:22:38,984: INFO: utils: created directory at: artifacts/test:]
# [2025-06-21 09:22:38,985: INFO: utils: created directory at: artifacts/test/results:]
# [2025-06-21 09:22:39,024: INFO: 2630596512: Using device: cuda:]
# [2025-06-21 09:22:39,246: INFO: 2630596512: Loaded model from artifacts/training/model_ensemblenet_best.pth:]
# Loaded model from artifacts/training/model_ensemblenet_best.pth
# [2025-06-21 09:22:39,354: INFO: 2630596512: Loaded model from artifacts/training/model_ensemblenet1_best.pth:]
# Loaded model from artifacts/training/model_ensemblenet1_best.pth
# [2025-06-21 09:22:39,558: INFO: 2630596512: Loaded model from artifacts/training/model_inception_v3_best.pth:]
# Loaded model from artifacts/training/model_inception_v3_best.pth
# [2025-06-21 09:22:39,593: INFO: 2630596512: Loaded model from artifacts/training/model_mnasnet_best.pth:]
# Loaded model from artifacts/training/model_mnasnet_best.pth
# [2025-06-21 09:22:39,627: INFO: 2630596512: Loaded model from artifacts/training/model_mobilenet_best.pth:]
# Loaded model from artifacts/training/model_mobilenet_best.pth
# [2025-06-21 09:22:39,652: INFO: 2630596512: Loaded model from artifacts/training/model_mobilenet_best.pth:]
# Loaded model from artifacts/training/model_mobilenet_best.pth
# [2025-06-21 09:22:39,822: INFO: 2630596512: Loaded model from artifacts/training/model_resnet_best.pth:]
# Loaded model from artifacts/training/model_resnet_best.pth
# [2025-06-21 09:22:39,854: INFO: 2630596512: Loaded model from artifacts/training/model_shufflenet_best.pth:]
# Loaded model from artifacts/training/model_shufflenet_best.pth
# [2025-06-21 09:22:39,868: INFO: 2630596512: Loaded model from artifacts/training/model_squeezenet_best.pth:]
# Loaded model from artifacts/training/model_squeezenet_best.pth
# [2025-06-21 09:22:40,386: INFO: 2630596512: Loaded model from artifacts/training/model_vit_best.pth:]
# Loaded model from artifacts/training/model_vit_best.pth
# [2025-06-21 09:22:40,392: INFO: 2630596512: Loading cached mean/std from artifacts/data_ingestion/test/mean.npy and artifacts/data_ingestion/test/std.npy:]
# [2025-06-21 09:22:40,442: INFO: 2630596512: Evaluating model: ensemblenet:]
# [2025-06-21 09:22:40,444: INFO: 2630596512: Evaluating model: EnsembleNet:]
# Evaluating model: EnsembleNet
# [2025-06-21 09:22:58,353: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:22:58,358: INFO: 2630596512: Evaluating model: ensemblenet1:]
# [2025-06-21 09:22:58,360: INFO: 2630596512: Evaluating model: EnsembleNet:]
# Evaluating model: EnsembleNet
# [2025-06-21 09:23:15,359: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:23:15,360: INFO: 2630596512: Evaluating model: inception_v3:]
# [2025-06-21 09:23:15,362: INFO: 2630596512: Evaluating model: Inception3:]
# Evaluating model: Inception3
# [2025-06-21 09:23:40,447: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:23:40,449: INFO: 2630596512: Evaluating model: mnasnet:]
# [2025-06-21 09:23:40,450: INFO: 2630596512: Evaluating model: MNASNet:]
# Evaluating model: MNASNet
# [2025-06-21 09:23:49,385: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:23:49,387: INFO: 2630596512: Evaluating model: mobilenet:]
# [2025-06-21 09:23:49,389: INFO: 2630596512: Evaluating model: MobileNetV3:]
# Evaluating model: MobileNetV3
# [2025-06-21 09:23:57,882: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:23:57,883: INFO: 2630596512: Evaluating model: resnet:]
# [2025-06-21 09:23:57,885: INFO: 2630596512: Evaluating model: ResNet:]
# Evaluating model: ResNet
# [2025-06-21 09:24:32,228: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:24:32,230: INFO: 2630596512: Evaluating model: shufflenet:]
# [2025-06-21 09:24:32,231: INFO: 2630596512: Evaluating model: ShuffleNetV2:]
# Evaluating model: ShuffleNetV2
# [2025-06-21 09:24:40,203: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:24:40,204: INFO: 2630596512: Evaluating model: squeezenet:]
# [2025-06-21 09:24:40,205: INFO: 2630596512: Evaluating model: SqueezeNet:]
# Evaluating model: SqueezeNet
# [2025-06-21 09:24:49,175: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:24:49,176: INFO: 2630596512: Evaluating model: vit:]
# [2025-06-21 09:24:49,178: INFO: 2630596512: Evaluating model: VisionTransformer:]
# Evaluating model: VisionTransformer
# [2025-06-21 09:27:41,077: INFO: 2630596512: Saved evaluation results to artifacts/test/results/results.csv:]
# [2025-06-21 09:27:41,092: INFO: 3525685937: Testing completed and metrics plots saved.:]
